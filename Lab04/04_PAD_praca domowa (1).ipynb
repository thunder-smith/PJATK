# %% [markdown]
# Zadanie 1 (5 pkt)
#
#
# Wgraj zawartość pliku orders.csv do ramki danych.
# Przyjrzyj się danym, wykorzystując poznane metody (describe, info, head) zanalizuj dane.
#
# Następnie:
#
#
#
# 1. Zamień order_date na format daty. Upewnij się, że w rezultacie data będzie w formacie: rok-miesiąc-dzień;
# 2. Sprawdź ile i jakie unikalne wartości znajdują się w kolumnie T-shirt category;
# 3. Wyczyść kolumnę tshirt_category normalizując nazwy produktów. Upewnij się, że dla każdej kategorii funkcjonuje jedna nazwa, np. zamiast white i wh jest tylko jedna wersja white. Skorzystaj z klasy string i metody apply;
# 4. Rozdziel kolumnę tshirt category na 3 kolumny: tshirt_type, która będzie mówiła o tym czy jest to koszulka, bluza czy coś innego, tshirt_size, która będzie informowała o rozmiarze koszulki, i tshirt_colour, która będzie informowała o kolorze. Skorzystaj z metody apply.
# 5. Znajdź zamówienia złożone między 31 grudnia 2014 a 2 sierpnia 2016.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
orders = pd.read_csv('/content/drive/MyDrive/orders.csv')
#print(orders.describe)
#print(orders.info)
#print(orders.head)
orders['order_date'] = pd.to_datetime(orders['order_date'], format='%Y-%m-%d')
print(orders['order_date'])
print(orders.tshirt_category.value_counts())
fixed = orders
fixed['tshirt_category'] = fixed.tshirt_category.str.replace('Wh ', 'White ')
fixed['tshirt_category'] = fixed.tshirt_category.str.replace('Bl ', 'Black ')
fixed['tshirt_category'] = fixed.tshirt_category.str.replace('Tshirt ', 'T-Shirt ')
fixed['tshirt_category'] = fixed.tshirt_category.str.replace('Tennis Shirt', 'T-Shirt')
print(fixed.tshirt_category.value_counts())
mask = (orders['order_date'] >= '2014-12-31') & (orders['order_date'] <= '2016-08-02')
print(orders.loc[mask])
# Out:
# 0       2016-09-04
# 1       2014-11-14
# 2       2017-02-26
# 3       2013-12-01
# 4       2015-10-22
#            ...
# 26547   2016-11-19
# 26548   2016-08-02
# 26549   2017-03-09
# 26550   2016-10-04
# 26551   2016-12-16
# Name: order_date, Length: 26552, dtype: datetime64[ns]
# Hoodie             6229
# White T-Shirt M    5547
# Black T-Shirt M    4454
# White T-Shirt F    3513
# Black T-Shirt F    3248
# Tennis Shirt       2153
# Wh Tshirt M         462
# Bl Tshirt M         377
# Wh Tshirt F         312
# Bl Tshirt F         257
# Name: tshirt_category, dtype: int64
# Hoodie             6229
# White T-Shirt M    6009
# Black T-Shirt M    4831
# White T-Shirt F    3825
# Black T-Shirt F    3505
# T-Shirt            2153
# Name: tshirt_category, dtype: int64
#       order_date  pages_visited         order_id customer_id  tshirt_category  \
# 4     2015-10-22             12  HTS-88ua9r-0001      88ua9r  White T-Shirt M
# 5     2016-01-15              9  HTS-061311-0003      061311  Black T-Shirt F
# 12    2015-11-24             15  HTS-je57lh-0001      je57lh           Hoodie
# 13    2015-10-10              8  HTS-252675-0002      252675  White T-Shirt M
# 15    2015-11-29             15  HTS-heb26i-0001      heb26i  Black T-Shirt F
# ...          ...            ...              ...         ...              ...
# 26496 2016-06-02              2  HTS-5b4bg6-0001      5b4bg6  Black T-Shirt F
# 26513 2016-07-05             12  HTS-bt08zd-0001      bt08zd  White T-Shirt F
# 26515 2016-07-27             17  HTS-gsc3f6-0001      gsc3f6           Hoodie
# 26540 2016-06-08              7  HTS-6ba0i0-0001      6ba0i0  White T-Shirt M
# 26548 2016-08-02              4  HTS-q0nm12-0001      q0nm12  White T-Shirt M
#
#        tshirt_price  tshirt_quantity
# 4              20.0                1
# 5              17.5                4
# 12             23.0                3
# 13             20.0                3
# 15             17.5                1
# ...             ...              ...
# 26496          17.5                1
# 26513          18.0                1
# 26515          23.0                1
# 26540          20.0                4
# 26548          20.0                1
#
# [12638 rows x 7 columns]

# %% [markdown]
# Zadanie 2 (4 pkt)
#
#
# Wgraj plik customers.csv do ramki danych.
#
# Następnie:
# 1. Wypisz kolumny;
# 2. Porównaj rozmiar ramki z rozmiarem ramki w zadaniu 1;
# 3. Zmień nazwę kolumny customerID  na customer_id upewniając się, że dane zmiana zostanie zapisana w pamięci dzięki jednemu z argumentów metody do zmiany nazwy kolumny;
# 4. Połącz ramkę orders z ramką customers po kolumnie customer_id. Z której metody skorzystasz? Zostaw odpowiedź w komentarzu do zadania w kodzie (np. blok komentarzem ‘’’ ‘’’).

# %%
customers = pd.read_csv('/content/drive/MyDrive/customers.csv')

print(orders.shape)
print(customers.shape)
customers.rename(columns={'customerID':'customer_id'}, inplace = True)
print(customers.head)

joined = orders.set_index("customer_id").join(customers.set_index("customer_id"), how='inner')
print(joined)
# Out:
# (26552, 7)
# (18766, 6)
# <bound method NDFrame.head of       customer_id gender   birthdate  \
# 0          886900      M   1953/10/5
# 1          038040      F  1946/12/21
# 2          698696      F   1983/12/1
# 3          sn9keh      M   1990/9/23
# 4          496907      M    1869/6/8
# ...           ...    ...         ...
# 18761      m1yyx6      M   1999/8/19
# 18762      744375      F  1941/10/22
# 18763      t6pxeo      F   1950/5/10
# 18764      930049      F  1979/10/22
# 18765      950728      M   1997/9/18
#
#                                               user_agent       ip_address  \
# 0      Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...     69.8.136.110
# 1      Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebK...    67.74.254.174
# 2      Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKi...    95.135.70.206
# 3      Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_6...    129.50.205.26
# 4      Mozilla/5.0 (Windows NT 6.1; Win64; x64) Apple...     81.98.234.29
# ...                                                  ...              ...
# 18761  Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...     95.142.4.155
# 18762  Mozilla/5.0 (Windows NT 6.1; Win64; x64) Apple...  119.219.176.225
# 18763  Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/53...   196.178.254.85
# 18764  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_3...   118.173.208.45
# 18765  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_3...   171.178.68.155
#
#        campaign
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
# ...         ...
# 18761      True
# 18762     False
# 18763     False
# 18764     False
# 18765     False
#
# [18766 rows x 6 columns]>
#             order_date  pages_visited         order_id  tshirt_category  \
# customer_id
# 000018      2015-12-22              8  HTS-000018-0003  White T-Shirt F
# 000018      2014-12-08             10  HTS-000018-0002  White T-Shirt M
# 000018      2013-12-20             18  HTS-000018-0001  Black T-Shirt F
# 000071      2014-10-14             13  HTS-000071-0001  White T-Shirt F
# 000071      2015-07-24             15  HTS-000071-0002  White T-Shirt M
# ...                ...            ...              ...              ...
# zyvn97      2015-09-04             17  HTS-zyvn97-0001  White T-Shirt F
# zyvn97      2016-12-23             12  HTS-zyvn97-0002  Black T-Shirt F
# zzolm4      2015-12-03             14  HTS-zzolm4-0001           Hoodie
# zzw4gs      2015-10-20             12  HTS-zzw4gs-0001          T-Shirt
# zzwlin      2016-12-01              6  HTS-zzwlin-0001  Black T-Shirt M
#
#              tshirt_price  tshirt_quantity gender   birthdate  \
# customer_id
# 000018               18.0                1      F   1954/8/19
# 000018               20.0                1      F   1954/8/19
# 000018               17.5                1      F   1954/8/19
# 000071               18.0                2      F  1966/12/20
# 000071               20.0                1      F  1966/12/20
# ...                   ...              ...    ...         ...
# zyvn97               18.0                1      F   1968/8/20
# zyvn97               17.5                1      F   1968/8/20
# zzolm4               23.0                1      M    1953/5/1
# zzw4gs               24.0                1      F  1954/11/26
# zzwlin               19.0                1      F  1964/11/21
#
#                                                     user_agent  \
# customer_id
# 000018       Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebK...
# 000018       Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebK...
# 000018       Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebK...
# 000071       Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_3...
# 000071       Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_3...
# ...                                                        ...
# zyvn97       Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...
# zyvn97       Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...
# zzolm4       Mozilla/5.0 (Windows NT 6.1; Win64; x64) Apple...
# zzw4gs       Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...
# zzwlin       Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebK...
#
#                   ip_address  campaign
# customer_id
# 000018         46.168.91.127     False
# 000018         46.168.91.127     False
# 000018         46.168.91.127     False
# 000071       106.140.104.103      True
# 000071       106.140.104.103      True
# ...                      ...       ...
# zyvn97         68.19.225.252     False
# zyvn97         68.19.225.252     False
# zzolm4        161.194.89.120     False
# zzw4gs         153.12.234.12     False
# zzwlin        65.185.114.123     False
#
# [25882 rows x 11 columns]

# %% [markdown]
# Zadanie 3 (1 pkt)
#
# Nową ramkę (połączenie orders i customers) zapisz do pliku csv, ale zapisz bez kolumny z indeksem.

# %%
joined.to_csv('/content/drive/MyDrive/joined.csv', index=False)
